# %%
# !pip install pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://rajeswarij1998:Guvi1234@guvicluster.uvmtk.mongodb.net/?retryWrites=true&w=majority&appName=Guvicluster")

# %%
client.test
# Out:
# Database(MongoClient(host=['guvicluster-shard-00-01.uvmtk.mongodb.net:27017', 'guvicluster-shard-00-00.uvmtk.mongodb.net:27017', 'guvicluster-shard-00-02.uvmtk.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Guvicluster', authsource='admin', replicaset='atlas-62a5k7-shard-0', tls=True), 'test')

# %%
client.list_database_names()
# Out:
# ['ProjectAirbnb', 'marks', 'admin', 'local']

# %%
db = client['ProjectAirbnb']

# %%
db.list_collection_names()
# Out:
# ['Listingreviews']

# %%
currentdb = db['Listingreviews']

# %%
listings = [i for i in currentdb.find()]
len(listings)
# Out:
# 5555

# %%
for i in currentdb.find():
    print(i)
# Out:
# {'_id': '1003530', 'listing_url': 'https://www.airbnb.com/rooms/1003530', 'name': 'New York City - Upper West Side Apt', 'summary': '', 'space': 'Murphy bed, optional second bedroom available. Wifi available, Hulu, Netflix, TV Eat-in kitchen. Bathroom with great shower/bath.  Washer/dryer in basement.', 'description': "Murphy bed, optional second bedroom available. Wifi available, Hulu, Netflix, TV Eat-in kitchen. Bathroom with great shower/bath.  Washer/dryer in basement. New York City! Great neighborhood - many terrific restaurants, bakeries, bagelries. Within easy walking distance are restaurants with the cuisines from India, Thailand, Japan, China, Mexico, South America and Europe.  As well as the many small independent stores that line Broadway, there chain stores such as Urban Outfitters (clothing), Whole Foods (groceries), Sephora (cosmetics), Michaels (crafts), and Modell's (sporting goods). Equidistant to Central Park and Riverside Park which have walking/running/biking trai
# ...

# %%
data=[]
for i in currentdb.find():
    data.append(i)
print(data)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
data[5554]
# Out:
# {'_id': '9936016',
#  'listing_url': 'https://www.airbnb.com/rooms/9936016',
#  'name': 'Alugo Apartamento na Tijuca',
#  'summary': 'Apartamento amplo que acomoda 6 pessoas. Um quarto com sofá cama de casal com armários, ventilador de teto e ar-condicionado. Sala com um sofá cama de casal, com ventilador de teto e climatizador. Dois banheiros, cozinha completa e área.',
#  'space': '',
#  'description': 'Apartamento amplo que acomoda 6 pessoas. Um quarto com sofá cama de casal com armários, ventilador de teto e ar-condicionado. Sala com um sofá cama de casal, com ventilador de teto e climatizador. Dois banheiros, cozinha completa e área.',
#  'neighborhood_overview': '',
#  'notes': '',
#  'transit': '',
#  'access': '',
#  'interaction': '',
#  'house_rules': 'Cuidar das instalações e objetos da casa em perfeito estado',
#  'property_type': 'Apartment',
#  'room_type': 'Entire home/apt',
#  'bed_type': 'Real Bed',
#  'minimum_nights': '1',
#  'maximum_nights': '1125',
# ...

# %%
data[1]
# Out:
# {'_id': '10133554',
#  'listing_url': 'https://www.airbnb.com/rooms/10133554',
#  'name': 'Double and triple rooms Blue mosque',
#  'summary': '',
#  'space': 'We are on the central city  Blue mosque 5 minutes  Hagia sopiha 4 minutes  Topkapi palace and archeology museums 5 minutes  Grand bazaar 10 minutes',
#  'description': 'We are on the central city  Blue mosque 5 minutes  Hagia sopiha 4 minutes  Topkapi palace and archeology museums 5 minutes  Grand bazaar 10 minutes We have bathroom,wc,İnternet in rooms and under rooms we have cafe bar restaurant and market anything you need we can help you 24 hours Hospitality Cankurtaran mahallesi akbıyık caddesi no 22 Sultanahmet Fatih İstanbul Tram 5 minutes  metro 10 minutes  Bus 10 minutes',
#  'neighborhood_overview': 'Cankurtaran mahallesi akbıyık caddesi no 22 Sultanahmet Fatih İstanbul',
#  'notes': '',
#  'transit': 'Tram 5 minutes  metro 10 minutes  Bus 10 minutes',
# ...

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#         _id                            listing_url  \
# 0   1003530   https://www.airbnb.com/rooms/1003530
# 1  10133554  https://www.airbnb.com/rooms/10133554
# 2  10059872  https://www.airbnb.com/rooms/10059872
# 3  10084023  https://www.airbnb.com/rooms/10084023
# 4  10091713  https://www.airbnb.com/rooms/10091713
#
#                                                name  \
# 0               New York City - Upper West Side Apt
# 1               Double and triple rooms Blue mosque
# 2                Soho Cozy, Spacious and Convenient
# 3                 City center private room with bed
# 4  Surry Hills Studio - Your Perfect Base in Sydney
#
#                                              summary  \
# 0
# 1
# 2  Clean, fully furnish, Spacious 1 bedroom flat ...
# 3  House is located 5mins walk from Sham Shui Po ...
# 4  This spacious, light filled studio has everyth...
#
#                                                space  \
# 0  Murphy bed, optional second bedroom available....
# ...

# %%
df['availability'][0]
# Out:
# {'availability_30': 0,
#  'availability_60': 0,
#  'availability_90': 0,
#  'availability_365': 93}

# %%
df[['30_days', '60_days', '90_days', '365_days']] = df['availability'].apply(pd.Series)

# %%
df.head()
# Out:
#         _id                            listing_url  \
# 0   1003530   https://www.airbnb.com/rooms/1003530
# 1  10133554  https://www.airbnb.com/rooms/10133554
# 2  10059872  https://www.airbnb.com/rooms/10059872
# 3  10084023  https://www.airbnb.com/rooms/10084023
# 4  10091713  https://www.airbnb.com/rooms/10091713
#
#                                                name  \
# 0               New York City - Upper West Side Apt
# 1               Double and triple rooms Blue mosque
# 2                Soho Cozy, Spacious and Convenient
# 3                 City center private room with bed
# 4  Surry Hills Studio - Your Perfect Base in Sydney
#
#                                              summary  \
# 0
# 1
# 2  Clean, fully furnish, Spacious 1 bedroom flat ...
# 3  House is located 5mins walk from Sham Shui Po ...
# 4  This spacious, light filled studio has everyth...
#
#                                                space  \
# 0  Murphy bed, optional second bedroom available....
# ...

# %%
df['review_scores'][0]
# Out:
# {'review_scores_accuracy': 10,
#  'review_scores_cleanliness': 9,
#  'review_scores_checkin': 10,
#  'review_scores_communication': 10,
#  'review_scores_location': 10,
#  'review_scores_value': 10,
#  'review_scores_rating': 94}

# %%
df[['review_accuracy', 'review_cleanliness', 'review_checkin', 'review_communication', 'review_location', 'review_value', 'review_rating']] = df['review_scores'].apply(pd.Series)

# %%
df.head()
# Out:
#         _id                            listing_url  \
# 0   1003530   https://www.airbnb.com/rooms/1003530
# 1  10133554  https://www.airbnb.com/rooms/10133554
# 2  10059872  https://www.airbnb.com/rooms/10059872
# 3  10084023  https://www.airbnb.com/rooms/10084023
# 4  10091713  https://www.airbnb.com/rooms/10091713
#
#                                                name  \
# 0               New York City - Upper West Side Apt
# 1               Double and triple rooms Blue mosque
# 2                Soho Cozy, Spacious and Convenient
# 3                 City center private room with bed
# 4  Surry Hills Studio - Your Perfect Base in Sydney
#
#                                              summary  \
# 0
# 1
# 2  Clean, fully furnish, Spacious 1 bedroom flat ...
# 3  House is located 5mins walk from Sham Shui Po ...
# 4  This spacious, light filled studio has everyth...
#
#                                                space  \
# 0  Murphy bed, optional second bedroom available....
# ...

# %%
df['host'][0]
# Out:
# {'host_id': '454250',
#  'host_url': 'https://www.airbnb.com/users/show/454250',
#  'host_name': 'Greta',
#  'host_location': 'New York, New York, United States',
#  'host_about': 'By now I have lived longer in the city than the country however I feel equally at home in each. I like to keep one foot in each and help others to do the same!',
#  'host_response_time': 'within an hour',
#  'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/f1022be4-e72a-4b35-b6d2-3d2736ddaff9.jpg?aki_policy=profile_small',
#  'host_picture_url': 'https://a0.muscache.com/im/pictures/f1022be4-e72a-4b35-b6d2-3d2736ddaff9.jpg?aki_policy=profile_x_medium',
#  'host_neighbourhood': '',
#  'host_response_rate': 100,
#  'host_is_superhost': True,
#  'host_has_profile_pic': True,
#  'host_identity_verified': True,
#  'host_listings_count': 3,
#  'host_total_listings_count': 3,
#  'host_verifications': ['email',
#   'phone',
#   'reviews',
#   'jumio',
#   'offline_government_id',
#   'government_id']}

# %%
keys = list(df['host'][0].keys())

# %%
print(keys)
# Out:
# ['host_id', 'host_url', 'host_name', 'host_location', 'host_about', 'host_response_time', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_response_rate', 'host_is_superhost', 'host_has_profile_pic', 'host_identity_verified', 'host_listings_count', 'host_total_listings_count', 'host_verifications']

# %%
df[['host_id', 'host_url', 'host_name', 'host_location', 'host_about', 'host_response_time', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_response_rate', 'host_is_superhost', 'host_has_profile_pic', 'host_identity_verified', 'host_listings_count', 'host_total_listings_count','host_verifications']] = df['host'].apply(pd.Series)

# %%
keys1 = list(df['address'][0].keys())

# %%
print(keys1)
# Out:
# ['street', 'suburb', 'government_area', 'market', 'country', 'country_code', 'location']

# %%
df[['street', 'suburb', 'government_area', 'market', 'country', 'country_code', 'location']] = df['address'].apply(pd.Series)

# %%
df.columns
# Out:
# Index(['_id', 'listing_url', 'name', 'summary', 'space', 'description',
#        'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',
#        'house_rules', 'property_type', 'room_type', 'bed_type',
#        'minimum_nights', 'maximum_nights', 'cancellation_policy',
#        'last_scraped', 'calendar_last_scraped', 'first_review', 'last_review',
#        'accommodates', 'bedrooms', 'beds', 'number_of_reviews', 'bathrooms',
#        'amenities', 'price', 'security_deposit', 'cleaning_fee',
#        'extra_people', 'guests_included', 'images', 'host', 'address',
#        'availability', 'review_scores', 'reviews', 'weekly_price',
#        'monthly_price', 'reviews_per_month', '30_days', '60_days', '90_days',
#        '365_days', 'review_accuracy', 'review_cleanliness', 'review_checkin',
#        'review_communication', 'review_location', 'review_value',
#        'review_rating', 'host_id', 'host_url', 'host_name', 'host_location',
# ...

# %%
keys2 = list(df['location'][0].keys())

# %%
print(keys2)
# Out:
# ['type', 'coordinates', 'is_location_exact']

# %%
df[['type', 'coordinates', 'is_location_exact']] = df['location'].apply(pd.Series)

# %%
df[['longitide','latitude']] = df['coordinates'].apply(pd.Series)

# %%
df.shape
# Out:
# (5555, 81)

# %%
keys4 = list(df['reviews'][0][0].keys())
keys4
# Out:
# ['_id', 'date', 'listing_id', 'reviewer_id', 'reviewer_name', 'comments']

# %%
reviews_df = pd.json_normalize(df['reviews'].explode())

# %%
reviews_df
# Out:
#               _id                 date listing_id reviewer_id reviewer_name  \
# 0         4351675  2013-04-29 04:00:00    1003530     3708459          Josh
# 1         4848277  2013-05-28 04:00:00    1003530     4609491          Ralf
# 2         5094175  2013-06-11 04:00:00    1003530     6741662          Mame
# 3         5497796  2013-07-02 04:00:00    1003530      474156          Lars
# 4         6933005  2013-08-31 04:00:00    1003530     6067127        Nicole
# ...           ...                  ...        ...         ...           ...
# 151419  108875304  2016-10-17 04:00:00    9887054    97695338        Hayden
# 151420  111029283  2016-10-29 04:00:00    9887054    32130541           Dew
# 151421  124437381  2017-01-01 05:00:00    9887054    45066433          Ilia
# 151422        NaN                  NaN        NaN         NaN           NaN
# 151423        NaN                  NaN        NaN         NaN           NaN
#
# ...

# %% [markdown]
# # Rename columns if necessary
# reviews_df = reviews_df.rename(columns={
#     'reviewer_name': 'Reviewer Name',
#     'date': 'Review Date',
#     'comments': 'Comments'
# })
#
# # Concatenate the original DataFrame with the new reviews DataFrame
# final_df = pd.concat([df.drop(columns='reviews'), reviews_df], axis=1)

# %%
pd.set_option('display.expand_frame_repr', False) 
pd.set_option('display.max_rows', None)
df.isnull().sum()
# Out:
# _id                             0
# listing_url                     0
# name                            0
# summary                         0
# space                           0
# description                     0
# neighborhood_overview           0
# notes                           0
# transit                         0
# access                          0
# interaction                     0
# house_rules                     0
# property_type                   0
# room_type                       0
# bed_type                        0
# minimum_nights                  0
# maximum_nights                  0
# cancellation_policy             0
# last_scraped                    0
# calendar_last_scraped           0
# first_review                 1388
# last_review                  1388
# accommodates                    0
# bedrooms                        5
# beds                           13
# number_of_reviews               0
# bathrooms                      10
# ...

# %%
df = df.drop(['weekly_price', 'monthly_price', 'reviews_per_month', 'review_accuracy', 'review_cleanliness', 'review_checkin', 'review_communication', 'review_location', 'review_value', 'review_rating', 'first_review', 'last_review', 'host_response_time', 'host_response_rate'], axis = 'columns')

# %%
df_heatmap = df[['market', 'suburb', 'government_area', 'property_type', 'room_type', 'price', '30_days', '60_days', '90_days', '365_days']]

# %%
df.shape
# Out:
# (5555, 67)

# %%
df['location'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df['location'][0]
#
# ...

# %%
df['security_deposit'].fillna(0, inplace=True)

# %%
df['cleaning_fee'].fillna(0, inplace=True)

# %%
df.shape
# Out:
# (5555, 67)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (5532, 67)

# %%
df.dtypes
# Out:
# _id                           object
# listing_url                   object
# name                          object
# summary                       object
# space                         object
# description                   object
# neighborhood_overview         object
# notes                         object
# transit                       object
# access                        object
# interaction                   object
# house_rules                   object
# property_type                 object
# room_type                     object
# bed_type                      object
# minimum_nights                object
# maximum_nights                object
# cancellation_policy           object
# last_scraped                  object
# calendar_last_scraped         object
# accommodates                   int64
# bedrooms                     float64
# beds                         float64
# number_of_reviews              int64
# bathrooms                    float64
# ...

# %%
df['longitide'] = df['longitide'].astype(float)
df['latitude'] = df['latitude'].astype(float)

df['minimum_nights'] = df['minimum_nights'].astype(int)
df['maximum_nights'] = df['maximum_nights'].astype(int)
df['bedrooms'] = df['bedrooms'].astype(int)
df['beds'] = df['beds'].astype(int)

# %%
df = df.drop(['last_scraped', 'calendar_last_scraped', 'images', 'review_scores', 'host_thumbnail_url', 'host_has_profile_pic'], axis = 'columns')

# %%
df = df.drop(['location', 'coordinates', 'host', 'address', 'availability' , 'reviews'], axis = 'columns')

# %%
df['host_location'].value_counts()
# Out:
# host_location
# NewYork,NewYork,UnitedStates                                                                481
# Barcelona,Catalonia,Spain                                                                   407
# Montreal,Quebec,Canada                                                                      331
# RiodeJaneiro,StateofRiodeJaneiro,Brazil                                                     252
# Porto,PortoDistrict,Portugal                                                                228
# Sydney,NewSouthWales,Australia                                                              228
# HongKong                                                                                    194
# Montreal,Québec,Canada                                                                      161
# Honolulu,Hawaii,UnitedStates                                                                130
# PT                                                                                          128
# ...

# %%
reviews_df.isnull().sum()
# Out:
# _id              1632
# date             1632
# listing_id       1632
# reviewer_id      1632
# reviewer_name    1633
# comments         1640
# dtype: int64

# %%
reviews_df.shape
# Out:
# (151424, 6)

# %%
reviews_df = reviews_df.dropna()

# %%
reviews_df.shape
# Out:
# (149783, 6)

# %%
df.isna().sum()
# Out:
# _id                          0
# listing_url                  0
# name                         0
# summary                      0
# space                        0
# description                  0
# neighborhood_overview        0
# notes                        0
# transit                      0
# access                       0
# interaction                  0
# house_rules                  0
# property_type                0
# room_type                    0
# bed_type                     0
# minimum_nights               0
# maximum_nights               0
# cancellation_policy          0
# accommodates                 0
# bedrooms                     0
# beds                         0
# number_of_reviews            0
# bathrooms                    0
# amenities                    0
# price                        0
# security_deposit             0
# cleaning_fee                 0
# extra_people                 0
# guests_included              0
# 30_days                      0
# ...

# %%
xc = (df[df['summary']=='<NA>'])
xc
# Out:
# Empty DataFrame
# Columns: [_id, listing_url, name, summary, space, description, neighborhood_overview, notes, transit, access, interaction, house_rules, property_type, room_type, bed_type, minimum_nights, maximum_nights, cancellation_policy, accommodates, bedrooms, beds, number_of_reviews, bathrooms, amenities, price, security_deposit, cleaning_fee, extra_people, guests_included, 30_days, 60_days, 90_days, 365_days, host_id, host_url, host_name, host_location, host_about, host_picture_url, host_neighbourhood, host_is_superhost, host_identity_verified, host_listings_count, host_total_listings_count, host_verifications, street, suburb, government_area, market, country, country_code, type, is_location_exact, longitide, latitude]
# Index: []
#
# [0 rows x 55 columns]

# %%
df.dtypes
# Out:
# _id                           object
# listing_url                   object
# name                          object
# summary                       object
# space                         object
# description                   object
# neighborhood_overview         object
# notes                         object
# transit                       object
# access                        object
# interaction                   object
# house_rules                   object
# property_type                 object
# room_type                     object
# bed_type                      object
# minimum_nights                 int32
# maximum_nights                 int32
# cancellation_policy           object
# accommodates                   int64
# bedrooms                       int32
# beds                           int32
# number_of_reviews              int64
# bathrooms                    float64
# amenities                     object
# price                          int64
# ...

# %%
avg_p = df_c.groupby('market')['30_days', 60_days, 90_days, 365_days].count().reset_index()
# Out:
#   Cell In[59], line 1
#     avg_p = df_c.groupby('market')['30_days', 60_days, 90_days, 365_days].count().reset_index()
#                                                 ^
# SyntaxError: invalid decimal literal

# %%
df = df.replace(to_replace=r'[\u4e00-\u9fff]+', value='', regex=True)

# %%
def remove_chinese_characters(text):
    if isinstance(text, str):
        return text.replace('\n', '').replace('\r', '').replace('\t', '').replace(' ', '').replace('\u3000', '').replace(' ', '').replace('\u200B', '').replace('\u200C', '').replace('\u200D', '').replace('\uFEFF', '') # Clean up whitespace characters
    return text

# Apply the function to the entire DataFrame
df = df.applymap(lambda x: remove_chinese_characters(x) if isinstance(x, str) else x)
# Out:
# C:\Users\rajij\AppData\Local\Temp\ipykernel_13028\2244659784.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: remove_chinese_characters(x) if isinstance(x, str) else x)

# %%
df.to_csv('Airbnb.csv',index=False)
df.to_csv('Airbnbreviewcomments.csv',index=False)

# %%
total_listing = df['name'].value_counts ().sum()

# %%
total_listing
# Out:
# 5532

# %%
countrylisting = df.groupby('country')['name'].count().reset_index()
countrylisting
# Out:
#          country  name
# 0      Australia   608
# 1         Brazil   606
# 2         Canada   649
# 3          China    19
# 4      Hong Kong   598
# 5       Portugal   552
# 6          Spain   633
# 7         Turkey   647
# 8  United States  1220

# %%
countrylisting = df.groupby('country').agg(
    listings_count=('name', 'count'),
    avg_price=('price', 'mean'),
    avg_availability=('365_days', 'mean'),
    avg_securitydeposit = ('security_deposit', 'mean'),
    avg_cleaningfee =('cleaning_fee', 'mean')

).reset_index()

# %%
countrylisting
# Out:
#          country  listings_count   avg_price  avg_availability  avg_securitydeposit  avg_cleaningfee
# 0      Australia             608  198.021382        101.600329           293.949013        69.891447
# 1         Brazil             606  525.346535        194.511551           701.462046       106.823432
# 2         Canada             649  100.117103        109.627119           207.721109        35.850539
# 3          China              19  405.368421        235.421053           440.368421        31.157895
# 4      Hong Kong             598  773.749164        141.561873           809.095318       117.938127
# 5       Portugal             552   69.132246        248.086957            59.242754        14.920290
# 6          Spain             633  100.826224        176.731438           169.870458        33.714060
# 7         Turkey             647  361.227202        253.188563           233.740340        35.846986
# ...

# %%
df_loc = df[['country', 'longitide', 'latitude', 'street', 'property_type', 'room_type', 'beds', 'number_of_reviews', 'minimum_nights', 'maximum_nights','365_days', 'price', 'security_deposit', 'cleaning_fee','amenities']]

# %%
df_loc.shape
# Out:
# (5532, 3)

# %%
count_avail = df.groupby('30_days')['name'].count().reset_index()
count_avail
# Out:
#     30_days  name
# 0         0  1797
# 1         1   124
# 2         2   125
# 3         3   119
# 4         4   151
# 5         5   134
# 6         6   136
# 7         7   112
# 8         8   119
# 9         9   117
# 10       10    98
# 11       11    98
# 12       12    96
# 13       13    91
# 14       14    80
# 15       15    79
# 16       16    73
# 17       17    86
# 18       18    83
# 19       19    82
# 20       20    71
# 21       21    73
# 22       22    67
# 23       23   142
# 24       24    73
# 25       25    70
# 26       26    58
# 27       27   118
# 28       28   144
# 29       29   282
# 30       30   634

# %%
#use ordinal encoder to convert categorical data into numerical data.
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()

OE = OrdinalEncoder()
df['market'] = OE.fit_transform(df[['market']])

OE = OrdinalEncoder()
df['suburb'] = OE.fit_transform(df[['suburb']])

OE = OrdinalEncoder
df['government_area'] = OE.fit_transform(df[['government_area']])

OE = OrdinalEncoder()
df['property_type'] = OE.fit_transform(df[['property_type']])

OE = OrdinalEncoder()
df['room_type'] = OE.fit_transform(df[['room_type']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 6
#       3 OE = OrdinalEncoder()
#       5 OE = OrdinalEncoder
# ----> 6 df['market'] = OE.fit_transform(df[['market']])
#       7 print(df)
#       8 OE = OrdinalEncoder
#
# TypeError: TransformerMixin.fit_transform() missing 1 required positional argument: 'X'
